# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
pd.set_option('max_columns', None)
df = pd.read_csv('C:/Users/caiom/IA/Arquivos/TCC/BD/TSE/votacao_candidato_munzona_2022_BRASIL_0.csv', encoding='Latin 1',sep=";")
df.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  12/10/2022   07:53:19         2022                2  Eleição Ordinária
# 1  12/10/2022   07:53:19         2022                2  Eleição Ordinária
# 2  12/10/2022   07:53:19         2022                2  Eleição Ordinária
# 3  12/10/2022   07:53:19         2022                2  Eleição Ordinária
# 4  12/10/2022   07:53:19         2022                2  Eleição Ordinária
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 1         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 2         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 3         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
# 4         1         546  ELEIÇÕES GERAIS ESTADUAIS 2022  02/10/2022
#
#   TP_ABRANGENCIA SG_UF SG_UE         NM_UE  CD_MUNICIPIO  NM_MUNICIPIO  \
# 0              E    SP    SP     SÃO PAULO         66850  MARTINÓPOLIS
# 1              E    MG    MG  MINAS GERAIS         45756      GUIDOVAL
# 2              E    MG    MG  MINAS GERAIS         40380        LONTRA
# 3              E    MG    MG  MINAS GERAIS         49310         PAIVA
# 4              E    PE    PE    PERNAMBUCO         24619  JOÃO ALFREDO
#
#    NR_ZONA  CD_CARGO           DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 0       71         7  Deputado Estadual  250001611741         13290
# 1      275         7  Deputado Estadual  130001605826         33170
# 2      255         7  Deputado Estadual  130001634041         10700
# 3      250         7  Deputado Estadual  130001634041         10700
# 4       88         7  Deputado Estadual  170001610719         77077
#
#                         NM_CANDIDATO         NM_URNA_CANDIDATO  \
# 0             LEANDRO CÂNDIDO SOARES            LEANDRO SOARES
# 1  SEBASTIAO DOS REIS PEDRO DA SILVA                TIAOZINHO
# 2         FERNANDA RIBEIRO DE SALLES  REPORTER FERNANDA SALLES
# 3         FERNANDA RIBEIRO DE SALLES  REPORTER FERNANDA SALLES
# 4      JORGE LUIS CARREIRO DE BARROS            JORGE CARREIRO
#
#   NM_SOCIAL_CANDIDATO  CD_SITUACAO_CANDIDATURA DS_SITUACAO_CANDIDATURA  \
# 0              #NULO#                       12                    APTO
# 1              #NULO#                       12                    APTO
# 2              #NULO#                       12                    APTO
# 3              #NULO#                       12                    APTO
# 4              #NULO#                       12                    APTO
#
#    CD_DETALHE_SITUACAO_CAND DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 0                         2                 DEFERIDO        Federação
# 1                         2                 DEFERIDO  Partido isolado
# 2                         2                 DEFERIDO  Partido isolado
# 3                         2                 DEFERIDO  Partido isolado
# 4                         2                 DEFERIDO  Partido isolado
#
#    NR_PARTIDO     SG_PARTIDO                       NM_PARTIDO  NR_FEDERACAO  \
# 0          13             PT        Partido dos Trabalhadores             2
# 1          33            PMN  Partido da Mobilização Nacional            -1
# 2          10   REPUBLICANOS                     REPUBLICANOS            -1
# 3          10   REPUBLICANOS                     REPUBLICANOS            -1
# 4          77  SOLIDARIEDADE                    Solidariedade            -1
#
#                                 NM_FEDERACAO   SG_FEDERACAO  \
# 0  Federação Brasil da Esperança - FE BRASIL  PT/PC do B/PV
# 1                                     #NULO#         #NULO#
# 2                                     #NULO#         #NULO#
# 3                                     #NULO#         #NULO#
# 4                                     #NULO#         #NULO#
#
#   DS_COMPOSICAO_FEDERACAO  SQ_COLIGACAO     NM_COLIGACAO  \
# 0       PC do B / PT / PV  250001681589        FEDERAÇÃO
# 1                  #NULO#  130001681300  PARTIDO ISOLADO
# 2                  #NULO#  130001682570  PARTIDO ISOLADO
# 3                  #NULO#  130001682570  PARTIDO ISOLADO
# 4                  #NULO#  170001681528  PARTIDO ISOLADO
#
#   DS_COMPOSICAO_COLIGACAO ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS  \
# 0       PT / PV / PC do B                   N                  0
# 1                     PMN                   N                  0
# 2            REPUBLICANOS                   N                  0
# 3            REPUBLICANOS                   N                  0
# 4           SOLIDARIEDADE                   N                  7
#
#   NM_TIPO_DESTINACAO_VOTOS  QT_VOTOS_NOMINAIS_VALIDOS  CD_SIT_TOT_TURNO  \
# 0                   Válido                          0                 5
# 1                   Válido                          0                 5
# 2                   Válido                          0                 5
# 3                   Válido                          0                 5
# 4                   Válido                          7                 5
#
#   DS_SIT_TOT_TURNO
# 0         SUPLENTE
# 1         SUPLENTE
# 2         SUPLENTE
# 3         SUPLENTE
# 4         SUPLENTE

# %%
df.drop(['DT_GERACAO'],axis=1,inplace=True)
df.drop(['HH_GERACAO'],axis=1,inplace=True) 
df.drop(['ANO_ELEICAO'],axis=1,inplace=True)
df.drop(['CD_TIPO_ELEICAO'],axis=1,inplace=True)
df.drop(['NM_TIPO_ELEICAO'],axis=1,inplace=True)
df.drop(['CD_ELEICAO'],axis=1,inplace=True)
df.drop(['DS_ELEICAO'],axis=1,inplace=True)
df.drop(['DT_ELEICAO'],axis=1,inplace=True)
df.drop(['NM_UE'],axis=1,inplace=True)
df.drop(['CD_MUNICIPIO'],axis=1,inplace=True)
df.drop(['CD_CARGO'],axis=1,inplace=True)
df.drop(['NR_CANDIDATO'],axis=1,inplace=True)
df.drop(['NM_CANDIDATO'],axis=1,inplace=True)
df.drop(['NM_URNA_CANDIDATO'],axis=1,inplace=True)
df.drop(['NM_SOCIAL_CANDIDATO'],axis=1,inplace=True)
df.drop(['CD_SITUACAO_CANDIDATURA'],axis=1,inplace=True)
df.drop(['CD_DETALHE_SITUACAO_CAND'],axis=1,inplace=True)
df.drop(['NM_PARTIDO'],axis=1,inplace=True)
df.drop(['NR_FEDERACAO'],axis=1,inplace=True)
df.drop(['NM_FEDERACAO'],axis=1,inplace=True)
df.drop(['SG_FEDERACAO'],axis=1,inplace=True)
df.drop(['SQ_COLIGACAO'],axis=1,inplace=True)
df.drop(['NM_COLIGACAO'],axis=1,inplace=True)
df.drop(['DS_COMPOSICAO_COLIGACAO'],axis=1,inplace=True)
df.drop(['CD_SIT_TOT_TURNO'],axis=1,inplace=True)
df.drop(['DS_SIT_TOT_TURNO'],axis=1,inplace=True)
df.head()
# Out:
#    NR_TURNO TP_ABRANGENCIA SG_UF SG_UE  NM_MUNICIPIO  NR_ZONA  \
# 0         1              E    SP    SP  MARTINÓPOLIS       71
# 1         1              E    MG    MG      GUIDOVAL      275
# 2         1              E    MG    MG        LONTRA      255
# 3         1              E    MG    MG         PAIVA      250
# 4         1              E    PE    PE  JOÃO ALFREDO       88
#
#             DS_CARGO  SQ_CANDIDATO DS_SITUACAO_CANDIDATURA  \
# 0  Deputado Estadual  250001611741                    APTO
# 1  Deputado Estadual  130001605826                    APTO
# 2  Deputado Estadual  130001634041                    APTO
# 3  Deputado Estadual  130001634041                    APTO
# 4  Deputado Estadual  170001610719                    APTO
#
#   DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  NR_PARTIDO     SG_PARTIDO  \
# 0                 DEFERIDO        Federação          13             PT
# 1                 DEFERIDO  Partido isolado          33            PMN
# 2                 DEFERIDO  Partido isolado          10   REPUBLICANOS
# 3                 DEFERIDO  Partido isolado          10   REPUBLICANOS
# 4                 DEFERIDO  Partido isolado          77  SOLIDARIEDADE
#
#   DS_COMPOSICAO_FEDERACAO ST_VOTO_EM_TRANSITO  QT_VOTOS_NOMINAIS  \
# 0       PC do B / PT / PV                   N                  0
# 1                  #NULO#                   N                  0
# 2                  #NULO#                   N                  0
# 3                  #NULO#                   N                  0
# 4                  #NULO#                   N                  7
#
#   NM_TIPO_DESTINACAO_VOTOS  QT_VOTOS_NOMINAIS_VALIDOS
# 0                   Válido                          0
# 1                   Válido                          0
# 2                   Válido                          0
# 3                   Válido                          0
# 4                   Válido                          7

# %%
print((((df.iloc[:,:]=="#NULO#").sum())*100)/2000000)
# Out:
# NR_TURNO                      0.00000
# TP_ABRANGENCIA                0.00000
# SG_UF                         0.00000
# SG_UE                         0.00000
# NM_MUNICIPIO                  0.00000
# NR_ZONA                       0.00000
# DS_CARGO                      0.00000
# SQ_CANDIDATO                  0.00000
# DS_SITUACAO_CANDIDATURA       0.00000
# DS_DETALHE_SITUACAO_CAND      0.00000
# TP_AGREMIACAO                 0.00000
# NR_PARTIDO                    0.00000
# SG_PARTIDO                    0.00000
# DS_COMPOSICAO_FEDERACAO      84.76375
# ST_VOTO_EM_TRANSITO           0.00000
# QT_VOTOS_NOMINAIS             0.00000
# NM_TIPO_DESTINACAO_VOTOS      0.00000
# QT_VOTOS_NOMINAIS_VALIDOS     0.00000
# dtype: float64
